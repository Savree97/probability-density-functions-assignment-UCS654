# %%
import pandas as pd
import numpy as np
import math

# %%
data=pd.read_csv("data.csv",encoding="latin1")
# Out:
# /tmp/ipython-input-3251056117.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("data.csv",encoding="latin1")

# %%
x=data["no2"].dropna().values

# %%
r=102317097

# %%
a_r=0.05*(r%7)
b_r=0.3*((r%5)+1)

# %%
z=x+a_r*np.sin(b_r*x)

# %%
mu=np.mean(z)
variance=np.mean((z-mu)**2)
lam=1/(2*variance)
c=math.sqrt(lam/math.pi)

# %%
print("mu =",mu)
print("lambda =",lam)
print("c =",c)
# Out:
# mu = 25.80823999034323
# lambda = 0.0014601889029994767
# c = 0.0215590482981183

# %%
import matplotlib.pyplot as plt

z_line=np.linspace(min(z),max(z),300)
pdf=c*np.exp(-lam*(z_line-mu)**2)

plt.plot(z_line,pdf)
plt.xlabel("z")
plt.ylabel("Probability Density")
plt.title("Estimated Probability Density Function")
plt.show()
